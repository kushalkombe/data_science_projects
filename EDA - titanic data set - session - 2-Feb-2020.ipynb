# %% [markdown]
# # Display scientific numbers into regular/normal numbers
# # https://re-thought.com/how-to-suppress-scientific-notation-in-pandas/

# %% [markdown]
# # DS project life cycle
#
# - Problem definition
# - Hypothesis Generation
# - Data Extraction /collection
# - Data Exploration and transformation
# - Predictive modeling
# - Model Deployment / Implementation
# - OPtimization after drifting

# %%
# Problem Statement
# Bad problem statement: Want to improve the profitability of credit card customers
## Want to increase the APR (interrest rate) of credit cards
## Want to deploy different APR for different segment of customers
## Want to identify the customers segments having lower default rate
## Want to have different APR and other benefits for different customers segments (on expected default rate) to maximize profit

# Good problem statement: Want to predict the default interest rate of customer

# %%
# Hypothesis Generation

# Listing down all the possiblee variable which might influence problem objectives
# What are factors, those can impact on the customer will default or not
# Income: Higher income means higher chance of financial stability that may lead to lower default rate
# Job Type: If the job is more stable that can also lead to lower default rate, Example: Fron end Sales job is less stable than data science job
# Credit History: Your previous good repayment behavior suggest that you know how to use credit products and that leads to lower default rate
# Education: Higher education is directly proporationate to awarenss about the use of credit products and that may impact the default rate also


# Should Hypothesis generation be done before or after ooking at the data?
# It should be done before looking at the data to avoid the bias
# Also helps to predict multiple possible options 
# does not neeed to analyze all client given data (watage of time many times)

# %%
# Data Extraction / collection
# Extract / Collect data from different sources and combine those for exploration and model building
# Few sources of data: Credit score from CIBIL (Credit score Beuro), Demographic of csutomers, Transactions hsitory, Payment history, Compititors pricing
# This data will prove or disprove yout hypothesis
#

# %%
# Data Exploration and transformation 
# Gain insights of the data
# Clients data is generally in tabular forms and making sense out of it is more harder than making sense from graphs/charts
# Good Analyst: Knows his/her data well
# Bad Analyst: Depends on tools and libraries
# Steps to follow to understand data well
# - Redaing the data file
# - Variable identification: Explanatory variables or Independent variables, Target or dependent variables, data types of each variable (Continuous/Categorical)
# - Univariate analysis: Analyse individual variable - histogram, Bar chart, frequency table, distribution
# - Bivariate analysis: find relationship between 2 variables - scatter plot
# - Missing value treatment: delete or impute using mean, mode, median
# - Outlier treatment: delete or making in normal range, find outliers using box plots
# - Variable Transformation: to make it in one scale - log, cube, square root (for skewed data)

# %%
# Reading data file
# read_csv, read_excel using pandas library
# Size of data: shape
# Name the variable in the data sets - columns
# check first few rows - head()

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\CJC-2\\Leftovertopics\\EDA - Titanic Data Set'

# %%
#importing pandas

import pandas as pd
# reading the csv file

df = pd.read_csv(".//data.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Data Exploration
# Variable identification
# dependent variable (Target variable) and independent variable identification: All supervised algorithms requires output and independet variables to build a model
# finding out continuous and categorical variable: Algorithms handles continuous and categorical data type seperately
# Target varaible: 'Survived'
# Indepedent variables: Which impacts target variable
# categorical variable - Survival(Y or N), Sex (Male, Female)
# Continuous variable: Age, fare ( can have min to max range)
# Categorical variables are stored as Objects
# continuous variables are stored in flote or int type

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Univariate analysis

# Explore one variable at a time
# Summarize the variable
# Make sense out of that summary to discover insights and anomalies or outliers, distribution
# Can draw box plot for each variable using pandas libraries

# Continuous univariate analysis (Tabular and graphical method)
#    Central tendency and dispersion - mean , median, standard deviation (Mean, Media, - Tabular method - Describe function)
#    Distribution of a variable - Symmetric, Right or left skewed - Histogram to check distribution - use pandas functiont o draw histogram
#    Presence of missing value and outliers - Box plot to detect outliers, use pandas boxplot function to plot boxplot

# Categorical Univariate analysis 
#

# %%
#using describe function on the continuous variable

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#plotting a histogram of age variable

df['Age'].plot.hist()

# %%
#plotting a boxplot for age variable

df['Age'].plot.box()

# %%
# Univariate analysis of categorical variables

# count or frequency of a variable - in numbers or percentage
# categorical variable in Titanic data sets - class, sex(Male,Female), port of embarkation

df['Sex'].value_counts()            # 65% male  #35% female
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts().plot.bar()

# %%
# % of male and females 
df['Sex'].value_counts()/len(df['Sex'])
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
(df['Sex'].value_counts()/len(df['Sex'])).plot.bar()

# %%
# Data Exploration

# Bivariate analsysis

# What, Why, How to do bivariate analysis

# Taller people have more weight as height increases - scatter plot - finds relation, finds anomalies as well
# Bivariate analysis betwee age Vs Fare, Gender - Mean Age (Male and Female - Mean age), Survival rate of male and female

# Continuous bivariate analsysis
 # Does increase in fare of ticket with increase in age? - Scatter plot (corelation - strong (strength) relationship between 2 variable using coefficient - +ve,-ve,neutral)

# Is the mean age (continuous variabel) of males (Categorical variable) different from the mean age of females? (t-test is used to compare means of 2 sample groups)

# Categorical Bivariate analysis
 # Does gender(Categorical variable) have any effect on the survival(categorical variable) rate? Chi square test (Observed and Expected surrvival rate) Is the survival rate statistical correct or not
 # Assume =  100 people were on Titanic and survived are 100 ie. MAle: 50 and feamle 50 would have survived
 # where we found only 20 males survived and 80 females survided that means

# %%
# Continuous - Continuous Bivariate Analysis

# %%
df.plot.scatter('Age','Fare')

df.corr()

df['Age'].corr(df['Fare'])
# Out:
# 0.0960666917690389

# %%
# Categorical - Continuous Bivariate Analysis

# %%
df.groupby('Sex')['Age'].mean().plot.bar()

# %%
#importing the scipy library for ttest

from scipy.stats import ttest_ind

male=df[df['Sex']=='male']
female=df[df['Sex']=='female']

ttest_ind(male['Age'],female['Age'],nan_policy='omit')
# Out:
# Ttest_indResult(statistic=2.499206354920835, pvalue=0.012671296797014266)

# %%
# Categorical - Categorical Bivariate Analysis

# %%
pd.crosstab(df['Sex'],df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
from scipy.stats import chi2_contingency

chi2_contingency(pd.crosstab(df['Sex'],df['Survived']))
# Out:
# (260.71702016732104,
#  1.1973570627755645e-58,
#  1L,
#  array([[193.47474747, 120.52525253],
#         [355.52525253, 221.47474747]]))

# %%
# Missing value treatement

# Types of missing value

# Identifying missing value

# Different methods to deal with missing values

# %%
# Why do we have missing values in the data set
# non responsiveness - salary to expose
# typos
# Faulty systems - not calibrated instruments
# Error while reading special characters

# %%
# Missing values can be found using describe() function or isnull() funtion
# either delete (column or row) or impute missing values
# Continuous missing variable : MEan, Median and regression model (KNN)
# For categorical missing values : Mode or classification model

# %%
df.describe()       # Age has missing values
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#identifying missing values in the dataframe

df.isnull()         # True means there is a missing value
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#dropping all ROWS where there are any missing values

df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
df.dropna().isnull().sum() # Now there are no  rows containingn missing values, it has not removed missing values from the df data frame as we have not used inplace or overwritten the data frame
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#dropping ALL the ROWS (default axis=0) where ALL the ENTRIES are MISSING 

df.dropna(how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.dropna(how='all').shape  # Check if any rows had all missing values in all columns. none such row found
# Out:
# (891, 12)

# %%
#dropping columns with ANY missing values , axis=1 means column , 3 columns did have at single NaN values and are removed so 9 columns are left

df.dropna(axis=1).shape
# Out:
# (891, 9)

# %%
df.dropna(axis=1, how='all').shape     # trying to remove columns having all missing values, but noe such column exists
# Out:
# (891, 12)

# %%
#filling all the missing values in a dataframe with 0

df.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df['Age'].fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       0.0
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      0.0
# 18     31.0
# 19      0.0
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      0.0
# 27     19.0
# 28      0.0
# 29      0.0
#        ...
# 861    21.0
# 862    48.0
# 863     0.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     0.0
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     0.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].fillna(df['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# 5      29.699118
# 6      54.000000
# 7       2.000000
# 8      27.000000
# 9      14.000000
# 10      4.000000
# 11     58.000000
# 12     20.000000
# 13     39.000000
# 14     14.000000
# 15     55.000000
# 16      2.000000
# 17     29.699118
# 18     31.000000
# 19     29.699118
# 20     35.000000
# 21     34.000000
# 22     15.000000
# 23     28.000000
# 24      8.000000
# 25     38.000000
# 26     29.699118
# 27     19.000000
# 28     29.699118
# 29     29.699118
#          ...
# 861    21.000000
# 862    48.000000
# 863    29.699118
# 864    24.000000
# 865    42.000000
# 866    27.000000
# 867    31.000000
# 868    29.699118
# 869     4.000000
# 870    26.000000
# 871    47.000000
# 872    33.000000
# 873    47.000000
# 874    28.000000
# 875    15.000000
# 876    20.000000
# 877    19.000000
# 878    29.699118
# 879    56.000000
# 880    25.000000
# 881    33.000000
# ...

# %%
df.describe(include='all')      # by default describe provides you only continuous summary but include parameter with all provides you summary of categorical and continuous values
# Out:
#         PassengerId    Survived      Pclass                       Name   Sex  \
# count    891.000000  891.000000  891.000000                        891   891
# unique          NaN         NaN         NaN                        891     2
# top             NaN         NaN         NaN  Graham, Mr. George Edward  male
# freq            NaN         NaN         NaN                          1   577
# mean     446.000000    0.383838    2.308642                        NaN   NaN
# std      257.353842    0.486592    0.836071                        NaN   NaN
# min        1.000000    0.000000    1.000000                        NaN   NaN
# 25%      223.500000    0.000000    2.000000                        NaN   NaN
# 50%      446.000000    0.000000    3.000000                        NaN   NaN
# 75%      668.500000    1.000000    3.000000                        NaN   NaN
# max      891.000000    1.000000    3.000000                        NaN   NaN
#
# ...

# %%
# Finding outliers
# reasons of outliers: Typos(Data entries error), measurement error(some values in Meters and KMs, Processing errors, ) 
# different types of outlier: Univariate outliers (can identify using box plot and bivariate analysis which can be found using scatter plot)
# identifying outliers - dta points < Q1 - 1.5 * IQR OR Data Points > Q3 + 1.5 * IQR 
# diffferent methods to deal with outliers - Delete outliers or transform the columns having outliers or dataframes or impute outliers or treat them seperately (rarely used)

# %% [markdown]
# Univariate outlier detection

# %%
df['Age'].plot.box()

# %% [markdown]
# Bivariate outlier detection

# %%
df.plot.scatter('Age', 'Fare')

# %%
df=df[df['Fare']<300]

# %%
# Recheck if outliers are vanished or not by plotting the graph again

df.plot.scatter('Age', 'Fare')

# %%
Replacing outlier in age with the mean age value

# %%
import numpy as np
df.loc[df['Age']>65, 'Age']=np.mean(df['Age'])

# %%
# Variable transformation

# What is variable transformation? replaceing orginal value of a column by some function like log(reducing values from major values), sqrt (applicable to positive values in the dataset), cuberoot (used for right skewed and applicable for +ve, -ve values), It affects the relationship with other variables
# binning - Used for converting continuous variables to categorical variables eg: age 10-20->A, 21-30->B, 31-40->C and so on

# Why do we use variable transformation? - To change a scale of variables. (10 variables are in KM and 1 variable in Meters, we change 1 mile variable to KMs or we rescale all variables altogether), also used to make distribution nromal from skewed distribution
# Common methods for transformation?

# %%
df['Age'].plot.hist()

# %%
np.power(df['Age'],1/3).plot.hist()

# %%
bins=[0,15,80]

group=['children', 'Adult']

df['type']=pd.cut(df['Age'],bins,labels=group)

# %%
df['type'].value_counts()
# Out:
# Adult       628
# children     83
# Name: type, dtype: int64
