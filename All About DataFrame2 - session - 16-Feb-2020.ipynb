# %%
# Applying filters

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\MasterCopy-Notes\\Course Contents\\CJC-2\\Sessions\\Pandas'

# %%
os.chdir('D:\\MasterCopy-Notes\\Course Contents\\CJC-2\\Sessions\\')

# %%
os.getcwd()
# Out:
# 'D:\\MasterCopy-Notes\\Course Contents\\CJC-2\\Sessions'

# %%
os.chdir('.//Pandas')

# %%
os.getcwd()
# Out:
# 'D:\\MasterCopy-Notes\\Course Contents\\CJC-2\\Sessions\\Pandas'

# %%
import pandas as pd
df = pd.read_csv("D:\\MasterCopy-Notes\\Course Contents\\CJC\\Code\\Practice\\data\\pandas_sales.csv")

# %%
df
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  12.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
df.set_index('month') # you can set field month as an index using  set_index function
# Out:
#        eggs  salt  spam
# month
# Jan      47  12.0    17
# Feb     110  50.0    31
# Mar     221  89.0    72
# Apr      77  87.0    20
# May     132   NaN    52
# Jun     205  60.0    55

# %%
df.set_index(['month','spam'])
# Out:
#             eggs  salt
# month spam
# Jan   17      47  12.0
# Feb   31     110  50.0
# Mar   72     221  89.0
# Apr   20      77  87.0
# May   52     132   NaN
# Jun   55     205  60.0

# %%
df.reset_index(drop=True)
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  12.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
# Using index_col to treat field month as an index
df1 = pd.read_csv("D:\\MasterCopy-Notes\\Course Contents\\CJC\\Code\\Practice\\data\\pandas_sales.csv", index_col = 'month')

# %%
df1
# Out:
#        eggs  salt  spam
# month
# Jan      47  12.0    17
# Feb     110  50.0    31
# Mar     221  89.0    72
# Apr      77  87.0    20
# May     132   NaN    52
# Jun     205  60.0    55

# %%
# find out rows having salt >60
# Understand that NaN is treated as Not a Number so can not compare
df.salt>60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# Name: salt, dtype: bool

# %%
#Get values with salt>60
df[df['salt']>60]
# Out:
#   month  eggs  salt  spam
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20

# %%
# Using & condition - multiple condition on the same field salt
#df[ (df['salt']> 60) & (df['salt']<88) ]    # brackets are must

# Another way to extract the same output
df[ (df.salt>60) & (df.salt<88)]   # brackets are must
# Out:
#   month  eggs  salt  spam
# 3   Apr    77  87.0    20

# %%
df
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  12.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
df1
# Out:
#        eggs  salt  spam
# month
# Jan      47  12.0    17
# Feb     110  50.0    31
# Mar     221  89.0    72
# Apr      77  87.0    20
# May     132   NaN    52
# Jun     205  60.0    55

# %%
# Copy one dataframe into other

# %%
df2=df             # Shallow copy, reference of the memory location is same, if one is changed, other will be changed

# %%
df2==df
# Out:
#    month  eggs   salt  spam
# 0   True  True   True  True
# 1   True  True   True  True
# 2   True  True   True  True
# 3   True  True   True  True
# 4   True  True  False  True
# 5   True  True   True  True

# %%
df[df2==df]
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  12.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
id(df), id(df2)
# Out:
# (2328633104200, 2328633104200)

# %%
df
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  12.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
df.loc[0,'salt'] = 100     # set value for 0 th row and salt column as 100 (original value was 12.0)

# %%
df
# Out:
#   month  eggs   salt  spam
# 0   Jan    47  100.0    17
# 1   Feb   110   50.0    31
# 2   Mar   221   89.0    72
# 3   Apr    77   87.0    20
# 4   May   132    NaN    52
# 5   Jun   205   60.0    55

# %%
# check now df2, it should have been chaged as well as both df and df2 are pointing to the same memory location
df2
# Out:
#   month  eggs   salt  spam
# 0   Jan    47  100.0    17
# 1   Feb   110   50.0    31
# 2   Mar   221   89.0    72
# 3   Apr    77   87.0    20
# 4   May   132    NaN    52
# 5   Jun   205   60.0    55

# %%
# let's revert the value
df2.loc[0,'salt'] = 47

# %%
df2
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  47.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
df1
# Out:
#        eggs  salt  spam
# month
# Jan      47  12.0    17
# Feb     110  50.0    31
# Mar     221  89.0    72
# Apr      77  87.0    20
# May     132   NaN    52
# Jun     205  60.0    55

# %%
df3 = df.copy()        # by default it is deep copy as value of deep argument is True, you can make it false intentionally to have shallow copy

# %%
df3
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  47.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
df3==df
# Out:
#    month  eggs   salt  spam
# 0   True  True   True  True
# 1   True  True   True  True
# 2   True  True   True  True
# 3   True  True   True  True
# 4   True  True  False  True
# 5   True  True   True  True

# %%
id(df), id(df3) # Both should be different and changing in one dataframe should not change other data frame
# Out:
# (2328633104200, 2328659670536)

# %%
df
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  47.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
df1
# Out:
#        eggs  salt  spam
# month
# Jan      47  12.0    17
# Feb     110  50.0    31
# Mar     221  89.0    72
# Apr      77  87.0    20
# May     132   NaN    52
# Jun     205  60.0    55

# %%
df2
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  47.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
df3
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  47.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
id(df), id(df1), id(df2), id(df3)
# Out:
# (2328633104200, 2328653533768, 2328633104200, 2328659670536)

# %%
# df and df2 are same, you can check now
df, df2
# Out:
# (  month  eggs  salt  spam
#  0   Jan    47  47.0    17
#  1   Feb   110  50.0    31
#  2   Mar   221  89.0    72
#  3   Apr    77  87.0    20
#  4   May   132   NaN    52
#  5   Jun   205  60.0    55,   month  eggs  salt  spam
#  0   Jan    47  47.0    17
#  1   Feb   110  50.0    31
#  2   Mar   221  89.0    72
#  3   Apr    77  87.0    20
#  4   May   132   NaN    52
#  5   Jun   205  60.0    55)

# %%
df2["cake"]=[0,0,10,20,30,40]       # Add one column called cake to df2, being df and df2 same memory address, both will have new column cake
# while adding column, please ensure no of values should be qual to no of rows in a dataframe else it returns error

# %%
df2
# Out:
#   month  eggs  salt  spam  cake
# 0   Jan    47  47.0    17     0
# 1   Feb   110  50.0    31     0
# 2   Mar   221  89.0    72    10
# 3   Apr    77  87.0    20    20
# 4   May   132   NaN    52    30
# 5   Jun   205  60.0    55    40

# %%
df
# Out:
#   month  eggs  salt  spam  cake
# 0   Jan    47  47.0    17     0
# 1   Feb   110  50.0    31     0
# 2   Mar   221  89.0    72    10
# 3   Apr    77  87.0    20    20
# 4   May   132   NaN    52    30
# 5   Jun   205  60.0    55    40

# %%
df2.all()      # return False when it finds at least one zero value
# Out:
# month     True
# eggs      True
# salt      True
# spam      True
# cake     False
# dtype: bool

# %%
#Find out all colums and rows having not a single  zero value, It will not display 'cake' column as it contains zero
df2.loc[:,df2.all()]      # all rows and display all columns having all non zero values in every row  else not
# Out:
#   month  eggs  salt  spam
# 0   Jan    47  47.0    17
# 1   Feb   110  50.0    31
# 2   Mar   221  89.0    72
# 3   Apr    77  87.0    20
# 4   May   132   NaN    52
# 5   Jun   205  60.0    55

# %%
# Add one more column called 'milk' with all zero values and one nan
import numpy as np
df2["milk"]=[0,0,0,0,0,np.nan]

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk
# 0   Jan    47  47.0    17     0   0.0
# 1   Feb   110  50.0    31     0   0.0
# 2   Mar   221  89.0    72    10   0.0
# 3   Apr    77  87.0    20    20   0.0
# 4   May   132   NaN    52    30   0.0
# 5   Jun   205  60.0    55    40   NaN

# %%
# Print all columns which do not have all zeros or nan, if a particular columns contains a single non zero value, it will be displayed 
df2.loc[:,df2.any()]
# Out:
#   month  eggs  salt  spam  cake
# 0   Jan    47  47.0    17     0
# 1   Feb   110  50.0    31     0
# 2   Mar   221  89.0    72    10
# 3   Apr    77  87.0    20    20
# 4   May   132   NaN    52    30
# 5   Jun   205  60.0    55    40

# %%
df2.loc[0,'salt']=0

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk
# 0   Jan    47   0.0    17     0   0.0
# 1   Feb   110  50.0    31     0   0.0
# 2   Mar   221  89.0    72    10   0.0
# 3   Apr    77  87.0    20    20   0.0
# 4   May   132   NaN    52    30   0.0
# 5   Jun   205  60.0    55    40   NaN

# %%
df2.loc[:,df2.any()]
# Out:
#   month  eggs  salt  spam  cake
# 0   Jan    47   0.0    17     0
# 1   Feb   110  50.0    31     0
# 2   Mar   221  89.0    72    10
# 3   Apr    77  87.0    20    20
# 4   May   132   NaN    52    30
# 5   Jun   205  60.0    55    40

# %%
df2.loc[0,'salt']=47

# %%
df2.loc[1,'cake']=np.nan

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk
# 0   Jan    47  47.0    17   0.0   0.0
# 1   Feb   110  50.0    31   NaN   0.0
# 2   Mar   221  89.0    72  10.0   0.0
# 3   Apr    77  87.0    20  20.0   0.0
# 4   May   132   NaN    52  30.0   0.0
# 5   Jun   205  60.0    55  40.0   NaN

# %%
# Print only columns having at least one Nan
df2.loc[:,df2.isnull().any()]
# Out:
#    salt  cake  milk
# 0  47.0   0.0   0.0
# 1  50.0   NaN   0.0
# 2  89.0  10.0   0.0
# 3  87.0  20.0   0.0
# 4   NaN  30.0   0.0
# 5  60.0  40.0   NaN

# %%
# Now remove nan from milk columns
df2.loc[5,'milk'] = 0

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk
# 0   Jan    47  47.0    17   0.0   0.0
# 1   Feb   110  50.0    31   NaN   0.0
# 2   Mar   221  89.0    72  10.0   0.0
# 3   Apr    77  87.0    20  20.0   0.0
# 4   May   132   NaN    52  30.0   0.0
# 5   Jun   205  60.0    55  40.0   0.0

# %%
# now check again : print only columns having at least one Nans
df2.loc[:,df2.isnull().any()]
# Out:
#    salt  cake
# 0  47.0   0.0
# 1  50.0   NaN
# 2  89.0  10.0
# 3  87.0  20.0
# 4   NaN  30.0
# 5  60.0  40.0

# %%
# Print all columns except Nans, only salt,cake columnwould go/disappear/vanish temporararily as we are giving inplace=True
df2.loc[:,df2.notnull().all()]
# Out:
#   month  eggs  spam  milk
# 0   Jan    47    17   0.0
# 1   Feb   110    31   0.0
# 2   Mar   221    72   0.0
# 3   Apr    77    20   0.0
# 4   May   132    52   0.0
# 5   Jun   205    55   0.0

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk
# 0   Jan    47  47.0    17   0.0   0.0
# 1   Feb   110  50.0    31   NaN   0.0
# 2   Mar   221  89.0    72  10.0   0.0
# 3   Apr    77  87.0    20  20.0   0.0
# 4   May   132   NaN    52  30.0   0.0
# 5   Jun   205  60.0    55  40.0   0.0

# %%
# add one column having all nan
# print only columns having all nans
df2['bread'] = [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    NaN
# 1   Feb   110  50.0    31   NaN   0.0    NaN
# 2   Mar   221  89.0    72  10.0   0.0    NaN
# 3   Apr    77  87.0    20  20.0   0.0    NaN
# 4   May   132   NaN    52  30.0   0.0    NaN
# 5   Jun   205  60.0    55  40.0   0.0    NaN

# %%
df2.loc[:,df2.isnull().all()]
# Out:
#    bread
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    NaN
# 1   Feb   110  50.0    31   NaN   0.0    NaN
# 2   Mar   221  89.0    72  10.0   0.0    NaN
# 3   Apr    77  87.0    20  20.0   0.0    NaN
# 4   May   132   NaN    52  30.0   0.0    NaN
# 5   Jun   205  60.0    55  40.0   0.0    NaN

# %%
df2.dropna?

# %%
#drop rows having Nans
#df2.dropna()         # nothing will be displayed as all rows contains at least one Nan in 'bread' column
df2.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [month, eggs, salt, spam, cake, milk, bread]
# Index: []

# %%
df2.dropna(axis=1)   # will drop only columns having at least one nans values  (salt and bread are disappeared)
# Out:
#   month  eggs  spam  milk
# 0   Jan    47    17   0.0
# 1   Feb   110    31   0.0
# 2   Mar   221    72   0.0
# 3   Apr    77    20   0.0
# 4   May   132    52   0.0
# 5   Jun   205    55   0.0

# %%
df2.dropna(axis='columns')      # salt and bread are disappeared, axis =1 and axis ='columns' both are same
# Out:
#   month  eggs  spam  milk
# 0   Jan    47    17   0.0
# 1   Feb   110    31   0.0
# 2   Mar   221    72   0.0
# 3   Apr    77    20   0.0
# 4   May   132    52   0.0
# 5   Jun   205    55   0.0

# %%
df2.dropna(subset=['salt','eggs'])  # removes rows having nans in any of the given columns
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    NaN
# 1   Feb   110  50.0    31   NaN   0.0    NaN
# 2   Mar   221  89.0    72  10.0   0.0    NaN
# 3   Apr    77  87.0    20  20.0   0.0    NaN
# 5   Jun   205  60.0    55  40.0   0.0    NaN

# %%
df2.dropna(subset=['salt','eggs','bread'])
# Out:
# Empty DataFrame
# Columns: [month, eggs, salt, spam, cake, milk, bread]
# Index: []

# %%
df2.replace(np.nan,0)          # replace nan with value 0
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    0.0
# 1   Feb   110  50.0    31   0.0   0.0    0.0
# 2   Mar   221  89.0    72  10.0   0.0    0.0
# 3   Apr    77  87.0    20  20.0   0.0    0.0
# 4   May   132   0.0    52  30.0   0.0    0.0
# 5   Jun   205  60.0    55  40.0   0.0    0.0

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    NaN
# 1   Feb   110  50.0    31   NaN   0.0    NaN
# 2   Mar   221  89.0    72  10.0   0.0    NaN
# 3   Apr    77  87.0    20  20.0   0.0    NaN
# 4   May   132   NaN    52  30.0   0.0    NaN
# 5   Jun   205  60.0    55  40.0   0.0    NaN

# %%
# replace nan with any value say 100
df2.replace(np.nan,100)
# Out:
#   month  eggs   salt  spam   cake  milk  bread
# 0   Jan    47   47.0    17    0.0   0.0  100.0
# 1   Feb   110   50.0    31  100.0   0.0  100.0
# 2   Mar   221   89.0    72   10.0   0.0  100.0
# 3   Apr    77   87.0    20   20.0   0.0  100.0
# 4   May   132  100.0    52   30.0   0.0  100.0
# 5   Jun   205   60.0    55   40.0   0.0  100.0

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    NaN
# 1   Feb   110  50.0    31   NaN   0.0    NaN
# 2   Mar   221  89.0    72  10.0   0.0    NaN
# 3   Apr    77  87.0    20  20.0   0.0    NaN
# 4   May   132   NaN    52  30.0   0.0    NaN
# 5   Jun   205  60.0    55  40.0   0.0    NaN

# %%
# replace nan values of salt column with its mean (salt columns mean)
mean = np.mean(df2['salt'])             # 333/5  (not considered a row having nan so 5 rows instead of 6)

# %%
mean
# Out:
# 66.6

# %%
df2.salt.replace(np.NaN,mean)
# Out:
# 0    47.0
# 1    50.0
# 2    89.0
# 3    87.0
# 4    66.6
# 5    60.0
# Name: salt, dtype: float64

# %%
df2
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    NaN
# 1   Feb   110  50.0    31   NaN   0.0    NaN
# 2   Mar   221  89.0    72  10.0   0.0    NaN
# 3   Apr    77  87.0    20  20.0   0.0    NaN
# 4   May   132   NaN    52  30.0   0.0    NaN
# 5   Jun   205  60.0    55  40.0   0.0    NaN

# %%
df2['salt'].replace(np.NaN,np.mean(df2['salt']))
# Out:
# 0    47.0
# 1    50.0
# 2    89.0
# 3    87.0
# 4    66.6
# 5    60.0
# Name: salt, dtype: float64

# %%
df2                # will not be able to see here as in prior command we did not use inplace=True or overwritten df2
# Out:
#   month  eggs  salt  spam  cake  milk  bread
# 0   Jan    47  47.0    17   0.0   0.0    NaN
# 1   Feb   110  50.0    31   NaN   0.0    NaN
# 2   Mar   221  89.0    72  10.0   0.0    NaN
# 3   Apr    77  87.0    20  20.0   0.0    NaN
# 4   May   132   NaN    52  30.0   0.0    NaN
# 5   Jun   205  60.0    55  40.0   0.0    NaN
